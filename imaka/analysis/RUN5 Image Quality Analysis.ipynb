# %% [markdown]
# # RUN5 Image Quality Analysis

# %%
from IPython.display import Image
from astropy.table import Table
from imaka.analysis import plot_stats
from imaka.analysis import add_data
import numpy as np
# %matplotlib inline
labels = [['20170517', 'closed'], ['20170518', 'closedB'], ['20170519', 'closedB'],['20170520', 'closedA'],['20170521', 'closed'],
          ['20170522', 'closed']]
data_dir_root = "/g/lu/data/imaka/RUN5/"; stats_dir_end = "/FLI/reduce/stats/"

# %% [markdown]
# ### Nightly Summary
#
# The table below gives a summary of the conditions (average MASS and DIMM seeing over the course of the observing time) and results (average empirical FWHM of all images for open and closed) of each observing night.

# %%
add_data.week_table(data_dir_root, stats_dir_end, labels)
Table.read(data_dir_root+"nightly_aves.fits")
# Out:
# Open File:  /g/lu/data/imaka/RUN5/20170517/FLI/reduce/stats/stats_open.fits
# Closed File:  /g/lu/data/imaka/RUN5/20170517/FLI/reduce/stats/stats_closed.fits
#                                      Image                                      ...
# ------------------------------------------------------------------------------- ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0063_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0067_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0071_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0075_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0080_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0084_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0088_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0092_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0096_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0100_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0104_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0108_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0112_o.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0124_o.fits ...
#                                      Image                                      ...
# ------------------------------------------------------------------------------- ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0064_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0068_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0072_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0076_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0077_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0081_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0085_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0089_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0093_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0097_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0101_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0105_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0109_c.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/FLD2/obj0113_c.fits ...
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Open File:  /g/lu/data/imaka/RUN5/20170518/FLI/reduce/stats/stats_open.fits
# Closed File:  /g/lu/data/imaka/RUN5/20170518/FLI/reduce/stats/stats_closedB.fits
#                                             Image                                              ...
# ---------------------------------------------------------------------------------------------- ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0020_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0026_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0032_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0034_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0038_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0039_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0040_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0042_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0045_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0048_o_clean.fits ...
#                                                                                            ... ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0099_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0102_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0105_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0108_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0111_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0113_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0116_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0119_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0122_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0125_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0128_o_clean.fits ...
# Length = 37 rows
#                                              Image                                              ...
# ----------------------------------------------------------------------------------------------- ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0035_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0036_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0037_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0043_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0046_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0049_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0052_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0055_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0058_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0061_cB_clean.fits ...
#                                                                                             ... ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0096_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0100_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0103_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0106_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0109_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0114_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0117_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0120_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0123_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0126_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce/FLD2_2/obj0129_cB_clean.fits ...
# Length = 30 rows
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Open File:  /g/lu/data/imaka/RUN5/20170519/FLI/reduce/stats/stats_open.fits
# Closed File:  /g/lu/data/imaka/RUN5/20170519/FLI/reduce/stats/stats_closedB.fits
#                                             Image                                              ...
# ---------------------------------------------------------------------------------------------- ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0004_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0005_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0009_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0012_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0015_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0018_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0021_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0024_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0027_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0030_o_clean.fits ...
#                                                                                            ... ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0140_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0143_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0146_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0149_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0152_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0155_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0158_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0161_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0164_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0167_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0170_o_clean.fits ...
# Length = 55 rows
#                                              Image                                              ...
# ----------------------------------------------------------------------------------------------- ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0010_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0013_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0016_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0019_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0022_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0025_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0028_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0031_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0034_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0037_cB_clean.fits ...
#                                                                                             ... ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0141_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0144_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0147_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0150_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0153_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0156_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0159_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0162_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0165_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0168_cB_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce/FLD2_2/obj0171_cB_clean.fits ...
# Length = 53 rows
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Open File:  /g/lu/data/imaka/RUN5/20170520/FLI/reduce/stats/stats_open.fits
# Closed File:  /g/lu/data/imaka/RUN5/20170520/FLI/reduce/stats/stats_closedA.fits
#                                            Image                                             ...
# -------------------------------------------------------------------------------------------- ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0014_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0017_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0029_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0023_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0026_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0029_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0032_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0035_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0038_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0041_o_clean.fits ...
#                                                                                          ... ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0062_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0065_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0068_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0071_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0074_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0077_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0080_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0083_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0086_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0089_o_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0092_o_clean.fits ...
# Length = 27 rows
#                                             Image                                             ...
# --------------------------------------------------------------------------------------------- ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0012_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0013_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0016_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0019_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0022_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0025_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0028_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0031_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0034_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0037_cA_clean.fits ...
#                                                                                           ... ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0061_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0064_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0067_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0070_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0073_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0076_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0079_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0082_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0085_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0088_cA_clean.fits ...
# /Users/astrouser/Desktop/Research/imaka/RUN5/20170520/FLI/reduce/FLD2_2/obj0091_cA_clean.fits ...
# Length = 28 rows
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Open File:  /g/lu/data/imaka/RUN5/20170521/FLI/reduce/stats/stats_open.fits
# Closed File:  /g/lu/data/imaka/RUN5/20170521/FLI/reduce/stats/stats_closed.fits
#                                             Image                                              ...
# ---------------------------------------------------------------------------------------------- ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0051_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0053_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0056_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0059_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0062_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0065_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0068_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0071_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0074_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0077_o_clean.fits ...
#                                                                                            ... ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0183_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0186_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0189_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0192_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0195_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0198_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0201_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0204_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0207_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0210_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0213_o_clean.fits ...
# Length = 54 rows
#                                             Image                                              ...
# ---------------------------------------------------------------------------------------------- ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0049_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0052_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0055_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0058_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0061_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0064_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0067_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0070_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0073_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0076_c_clean.fits ...
#                                                                                            ... ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0182_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0185_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0188_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0191_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0194_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0197_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0200_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0203_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0206_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0209_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce/FLD2_2/obj0212_c_clean.fits ...
# Length = 55 rows
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Open File:  /g/lu/data/imaka/RUN5/20170522/FLI/reduce/stats/stats_open.fits
# Closed File:  /g/lu/data/imaka/RUN5/20170522/FLI/reduce/stats/stats_closed.fits
#                                             Image                                              ...
# ---------------------------------------------------------------------------------------------- ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0124_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0129_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0135_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0141_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0147_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0153_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0159_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0165_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0171_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0177_o_clean.fits ...
#                                                                                            ... ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0207_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0215_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0221_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0227_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0233_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0239_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0245_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0251_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0257_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0263_o_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0269_o_clean.fits ...
# Length = 25 rows
#                                             Image                                              ...
# ---------------------------------------------------------------------------------------------- ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0126_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0128_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0134_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0140_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0146_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0152_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0158_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0164_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0170_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0176_c_clean.fits ...
#                                                                                            ... ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0212_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0214_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0220_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0226_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0232_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0238_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0244_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0250_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0256_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0262_c_clean.fits ...
# /Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce/FLD2_2/obj0268_c_clean.fits ...
# Length = 26 rows
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# Filter not found: defaulting to 500 nm
# ----------------------------------------------------------
# KeyError                 Traceback (most recent call last)
# <ipython-input-2-4fbd916b6085> in <module>()
# ----> 1 add_data.week_table(data_dir_root, stats_dir_end, labels)
#       2 Table.read(data_dir_root+"nightly_aves.fits")
#
# ~/code/python/imaka/imaka/analysis/add_data.py in week_table(data_dir_root, stats_dir_end, labels)
#     292         closed_ave[i] = scale * np.mean(c_data * c_binfac * (500/c_filt)**(-1/5))
#     293
# --> 294         MASS_ave[i] = np.mean(np.concatenate((np.array(closed_data['MASS']), np.array(open_data['MASS'])), axis=0))
#     295         DIMM_ave[i] = np.mean(np.concatenate((np.array(closed_data['DIMM']), np.array(open_data['DIMM'])), axis=0))
#     296
#
# /anaconda/lib/python3.6/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1220     def __getitem__(self, item):
#    1221         if isinstance(item, str):
# -> 1222             return self.columns[item]
#    1223         elif isinstance(item, (int, np.integer)):
#    1224             return self.Row(self, item)
#
# /anaconda/lib/python3.6/site-packages/astropy/table/table.py in __getitem__(self, item)
#     104         """
#     105         if isinstance(item, str):
# --> 106             return OrderedDict.__getitem__(self, item)
#     107         elif isinstance(item, (int, np.integer)):
#     108             return self.values()[item]
#
# KeyError: 'MASS'

# %% [markdown]
# ### FWHM vs Seeing
#
# The data in the plot below shows empirical FWHM as a function of seeing, each data point representing one frame.  Ideally, the FWHM in open loop should match the DIMM seeing, while the closed loop should match MASS seeing, having data points fall along the diagonal black line.  Though open loop data at high seeing seems to be better than ideal, our closed loop data is generally above the black line, that is, not reaching the PSF we expect from the seeing measurments.

# %%
plot_stats.plot_week_fwhm(labels, data_dir_root, stats_dir_end, "FWHM vs Seeing for June 2017 Run")

# %% [markdown]
# ### FWHM Histogram
#
# The histogram below represents the distribtion of empirical FWHM measured in all the data, comparing open and closed loop observations.  Besides the clear shift of the distribution to lower FWHM in closed loop, the shape of the distrubtion is notably different as well, showing a narrower spread in closed loop.

# %%
labels = [['20170517', 'closed', 806], ['20170518', 'closedB', 806], ['20170519', 'closedB', 806],['20170520', 'closedA', 806], ['20170521', 'closed', 806], ['20170522', 'closed', 806]]
plot_stats.plot_hist(labels, data_dir_root, stats_dir_end, 'February Run FWHM Histogram')

# %% [markdown]
# ### Encircled Energy Profile
#
# The plots below show the ratio of closed to open loop encircled energies as a function of the difference between DIMM and MASS seeing.  Besides the lack of correlation between fractional improvment of the EE and seeing, we were suprised to see the discrepancy between improvements in the FWHM and in the 50% EE diameter.  Though the sharpness of the brightness profile could create some difference between these two metrics, we expect to see similar amounts of improvement; while the FWHMs improve by almost a factor of two, the 50% EE improves on average by only about 25%.

# %%
plot_stats.plot_EE(labels, data_dir_root, stats_dir_end)

# %% [markdown]
# ### Nightly FWHM with Seeing
#
# Each data point in the plots below represent the average FWHM of all sources in a single frame. The solid lines represent the MASS-DIMM seeing as reported by Mauna Kea Weather Services. Only seeing observations at the same time as images are shown below.  In addition to matching the seeing data to the times of observations, the times of closed loop images were matched as closely as possible in time to the open loop frame in an attempt to show the difference in open and closed loop images with the same seeing conditions.
#
# Looking at the plots, the DIMM seeing generally does a good job of tracing the open loop data.  The MASS doesn't trace closed loop quite as well, particularly at very low seeing conditions.  Our data generally follows the seeing data up until a minimum of around 0.3 as, where our FWHM seems to reach a lower limit.  Potentially augmenting this discrepancy, the MASS software on Mauna Kea may currently be overestimating their seeing, calling this data 'prelimiary'.

# %%
root_dir = "/Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/reduce"; open_file = root_dir + "/stats/stats_open_mdp.fits"; closed_file = root_dir + "/stats/stats_closed_mdp.fits"; plots_dir = root_dir + "/plots/"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file, 'emp_fwhm', "2017-05-17: FWHM and Seeing over time", plots_dir)

# %%
root_dir = "/Users/fatimaabdurrahman/Desktop/Research/RUN5/20170518/FLI/reduce"; open_file = root_dir + "/stats/stats_open_mdp.fits"; closed_file = root_dir + "/stats/stats_closedA_mdp.fits"; plots_dir = root_dir + "/plots/"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file, 'emp_fwhm', "2017-05-18: FWHM and Seeing over time", plots_dir)

# %%
root_dir = "/Users/fatimaabdurrahman/Desktop/Research/RUN5/20170519/FLI/reduce"; open_file = root_dir + "/stats/stats_open_mdp.fits"; closed_file = root_dir + "/stats/stats_closedA_mdp.fits"; plots_dir = root_dir + "/plots/"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file, 'emp_fwhm', "2017-05-19: FWHM and Seeing over time", plots_dir)

# %%
root_dir = "/Users/fatimaabdurrahman/Desktop/Research/RUN5/20170520/FLI/reduce"; open_file = root_dir + "/stats/stats_open_mdp.fits"; closed_file = root_dir + "/stats/stats_closedA_mdp.fits"; plots_dir = root_dir + "/plots/"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file, 'emp_fwhm', "2017-05-20: FWHM and Seeing over time", plots_dir)

# %%
root_dir = "/Users/fatimaabdurrahman/Desktop/Research/RUN5/20170521/FLI/reduce"; open_file = root_dir + "/stats/stats_open_mdp.fits"; closed_file = root_dir + "/stats/stats_closedA_mdp.fits"; plots_dir = root_dir + "/plots/"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file, 'emp_fwhm', "2017-05-21: FWHM and Seeing over time", plots_dir)

# %%
root_dir = "/Users/fatimaabdurrahman/Desktop/Research/RUN5/20170522/FLI/reduce"; open_file = root_dir + "/stats/stats_open_mdp.fits"; closed_file = root_dir + "/stats/stats_closedA_mdp.fits"; plots_dir = root_dir + "/plots/"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file, 'emp_fwhm', "2017-05-22: FWHM and Seeing over time", plots_dir)
