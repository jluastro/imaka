# %%
from IPython.display import Image
from astropy.table import Table
from imaka.analysis import plot_stats
from imaka.analysis import add_data
import numpy as np
# %matplotlib inline
labels = [['20170517', 'closed'], ['20170518', 'closedB'], ['20170519', 'closedB'],['20170520', 'closedA']]
data_dir_root = "/Users/fatimaabdurrahman/Desktop/Research/RUN5/"; stats_dir_end = "/FLI/reduce/stats/"

# %%
add_data.week_table(data_dir_root, stats_dir_end, labels)
Table.read(data_dir_root+"nightly_aves.fits")
# Out:
# <Table length=4>
#  HST_Date  ave_open_fwhm  ave_closed_fwhm    ave_DIMM        ave_MASS
#   str10       float64         float64        float64         float64
# ---------- -------------- --------------- -------------- ---------------
# 2017-05-17  1.20588376898  0.349109333558 0.405357142857 0.0992857142857
# 2017-05-18 0.661426270892  0.313686947828 0.427164179104  0.223134328358
# 2017-05-19 0.763243975067   0.43392074886 0.633518518519  0.450462962963
# 2017-05-20 0.743887243411  0.414875470377 0.744181818182  0.268727272727

# %%
plot_stats.plot_week_fwhm(labels, data_dir_root, stats_dir_end, "FWHM vs Seeing for June 2017 Run")

# %%
labels = [['20170517', 'closed', 806], ['20170518', 'closedB', 806], ['20170519', 'closedB', 806],['20170520', 'closedA', 806]]
plot_stats.plot_hist(labels, data_dir_root, stats_dir_end, 'February Run FWHM Histogram')

# %%
plot_stats.plot_EE(labels, data_dir_root, stats_dir_end)

# %%
root_dir = "/Users/fatimaabdurrahman/Desktop/Research/RUN5/20170517/FLI/"

stats_dir = root_dir + "reduce/stats/"; plots_dir =root_dir + "reduce/plots/"
open_file = stats_dir +"stats_open_mdp.fits"; closed_file = stats_dir+ "stats_closed_mdp.fits"
closedA_file = stats_dir + 'stats_closedA_mdp.fits'; closedB_file = stats_dir + 'stats_closedB_mdp.fits'
plot_stats.plot_fwhmvt(open_file, closed_file, 'emp_fwhm', "2017-02-14: FWHM and Seeing over time in I filter", plots_dir)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-a6df6945da70> in <module>()
#       4 open_file = stats_dir +"stats_open_mdp.fits"; closed_file = stats_dir+ "stats_closed_mdp.fits"
#       5 closedA_file = stats_dir + 'stats_closedA_mdp.fits'; closedB_file = stats_dir + 'stats_closedB_mdp.fits'
# ----> 6 plot_stats.plot_fwhmvt(open_file, closed_file, 'emp_fwhm', "2017-02-14: FWHM and Seeing over time in I filter", plots_dir)
#
# /Users/fatimaabdurrahman/Desktop/Research/imaka/imaka/analysis/plot_stats.py in plot_fwhmvt(open_file, closed_file, comp_col, title, plots_dir)
#    1103
#    1104     plt.figure(1, figsize=(12, 6))
# -> 1105     plt.errorbar(times, data1*calib, yerr=open_err, fmt='o', label="Open")
#    1106     plt.errorbar(times, data2*calib, yerr=closed_err, fmt='ro', label="Closed")
#    1107     plt.plot(times, dimm, 'b-')
#
# ...
