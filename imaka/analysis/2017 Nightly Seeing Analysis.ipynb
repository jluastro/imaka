# %%
from imaka.analysis import plot_stats
# %matplotlib inline
# Out:
# /anaconda/lib/python3.6/site-packages/astropy/config/configuration.py:541: ConfigurationMissingWarning: Configuration defaults will be used due to FileExistsError:17 on None
#   warn(ConfigurationMissingWarning(msg))

# %% [markdown]
# # 2017 Nightly Seeing Analysis
#
# ### The plots below compare telemetry seeing data to that of Mauna Kea Weather Service's reported data for the three 2017 runs.

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN3/20170109/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN3/20170110/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN3/20170111/FLI/reduce/stats/')

# %% [markdown]
# # Note: 1-13-2017 plot has no corresponding date bc the mass/dimm times don't overlap at all... Might be units of time in telemetry files?

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN3/20170113/FLI/reduce/stats/')
# Out:
# /anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6201: RuntimeWarning: invalid value encountered in true_divide
#   m = (m.astype(float) / db) / m.sum()

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN4/20170214/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN4/20170215/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN4/20170216/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN4/20170217/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN4/20170218/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN5/20170517/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN5/20170518/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN5/20170519/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN5/20170520/FLI/reduce/stats/')

# %%
plot_stats.compare_seeing('//g/lu/data/imaka/RUN5/20170521/FLI/reduce/stats/')
