# %% [markdown]
# Multi-day data is only for first three days: no MASS data exists for Thursday, Friday has two sets that still have to be combined

# %%
import plot_stats
# %matplotlib inline

# %%
#20170109
open_file = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170109/fli/reduce/stats/stats_open_mdp.fits"
closed_file = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170109/fli/reduce/stats/stats_closed_mdp.fits"
plots_dir = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170109/fli/reduce/plots/"
plot_stats.plot_fwhmvt(open_file, closed_file, 'emp_fwhm', 658, "2017-1-9: FWHM and Seeing over time in R filter", plots_dir)

# %%
#20170110
open_file = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170110/fli/reduce/stats/stats_open_mdp.fits"
closed_file = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170110/fli/reduce/stats/stats_closed_mdp.fits"
plots_dir = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170110/fli/reduce/plots/"
plot_stats.plot_fwhmvt(open_file, closed_file, 'emp_fwhm', 658, "2017-1-10: FWHM and Seeing over time in R filter", plots_dir)

# %%
#20170111
open_file = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170111/fli/reduce/stats/stats_open_mdp.fits"
closed_file = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170111/fli/reduce/stats/stats_closed_mdp.fits"
plots_dir = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170111/fli/reduce/plots/"
plot_stats.plot_fwhmvt(open_file, closed_file, 'emp_fwhm', 658, "2017-1-11: FWHM and Seeing over time in R filter", plots_dir)

# %%
#20170112 - no MASS data this night
open_file = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170112/fli/reduce/stats/stats_open_mdp.fits"
closed_file = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170112/fli/reduce/stats/stats_closed_mdp.fits"
plots_dir = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170112/fli/reduce/plots/"
plot_stats.plot_fwhmvt(open_file, closed_file, 'emp_fwhm', 658, "2017-1-12: FWHM and Seeing over time in R filter", plots_dir)

# %%
#20170113
open_file = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170113/fli/reduce/stats/stats_open2_mdp.fits"
closed_file = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170113/fli/reduce/stats/stats_closed2_mdp.fits"
plots_dir = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/20170113/fli/reduce/plots/"
plot_stats.plot_fwhmvt(open_file, closed_file, 'emp_fwhm', 658, "2017-1-13: FWHM and Seeing over time in R filter", plots_dir)

# %%
labels = [['20170109', 'closed', 658], ['20170110', 'closed', 658], ['20170111', 'closed', 658], ['20170112', 'closed', 658]]
data_dir_root = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/"; stats_dir_end = "/fli/reduce/stats/"
title = "FWHM vs Seeing for January 2017 Run"
plot_stats.plot_week_fwhm(labels, data_dir_root, stats_dir_end, title)

# %%
labels = [['20170109', 'closed'], ['20170110', 'closed'], ['20170111', 'closed']]
data_dir_root = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/"; stats_dir_end = "/fli/reduce/stats/"
plot_stats.plot_EE(labels, data_dir_root, stats_dir_end)

# %%
labels = [['20170109', 'closed', 658], ['20170110', 'closed', 658], ['20170111', 'closed', 658], ['20170112', 'closed', 658]]
data_dir_root = "/Users/astrouser/Desktop/Reserach/imaka/RUN3/"; stats_dir_end = "/fli/reduce/stats/"
title = "January Run FWHM Histogram"
plot_stats.plot_hist(labels, data_dir_root, stats_dir_end, title)
