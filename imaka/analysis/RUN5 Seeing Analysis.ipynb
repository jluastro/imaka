# %%
from imaka.analysis import plot_stats
# %matplotlib inline

# %% [markdown]
# # Seeing Comparison
#
# The plots below compare Olivier's seeing datato that of Mauna Kea Weather Service's reported data for the February run.  For each night, there is a pair of plots.  The top shows integrated seeing, and the bottom shows free atmosphere seeing.
#
# #### LEGEND:
#
#     Light colors: Mauna Kea MASS/DIMM
#
#     Dark Colors: Olivier's Data

# %%
plot_stats.compare_seeing('20170517')

# %%
plot_stats.compare_seeing('20170518')

# %%
plot_stats.compare_seeing('20170519')

# %%
plot_stats.compare_seeing('20170520')

# %%
plot_stats.compare_seeing('20170521')

# %%
plot_stats.compare_seeing('20170522')
