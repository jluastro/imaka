# %% [markdown]
# # Average MASS profiles

# %%
from imaka.analysis import plot_stats
from imaka.reduce import massdimm

# %%
UT_date = '20170521'
massdimm_dir = '/Users/dorafohring/Desktop/imaka/massdimm/'
stats_dir = '/Users/dorafohring/Desktop/imaka/data/'

# %% [markdown]
# Get stats FITS tables

# %%
plot_stats.fetch_stats_from_onaga([UT_date], output_root=stats_dir)
# Out:
# imaka@onaga.ifa.hawaii.edu:/Volumes/DATA4/imaka/20170521/fli/reduce/stats/stats*.fits
# /Users/dorafohring/Desktop/imaka/data//20170521/fli/reduce/stats/

# %% [markdown]
# Get MASS/DIMM files

# %%
save_suffixes = ['open','closedA', 'closed', 'stacks']

# %%
massdimm.fetch_data(utDate=UT_date, saveTo=massdimm_dir)
for suffix in save_suffixes:
    massdimm.append_mass_dimm(stats_dir + '{0}/fli/reduce/stats/stats_{1}.fits'.format(UT_date, suffix), massdimm_dir)
# Out:
# Saving MASS/DIMM data to directory:
# /Users/dorafohring/Desktop/imaka/massdimm/

# %% [markdown]
# Plots:

# %%
plot_stats.plot_profile('20170109', suffixes=['open', 'closed'], root_dir=stats_dir)

# %%
plot_stats.plot_all_profiles(['20170109'], root_dir=stats_dir)
# Out:
# > /Users/dorafohring/Desktop/git/imaka/imaka/analysis/plot_stats.py(899)plot_all_profiles()
# -> for ii in range(len(stats)):
# (Pdb) c
# > /Users/dorafohring/Desktop/git/imaka/imaka/analysis/plot_stats.py(898)plot_all_profiles()
# -> pdb.set_trace()
# (Pdb) c
# > /Users/dorafohring/Desktop/git/imaka/imaka/analysis/plot_stats.py(899)plot_all_profiles()
# -> for ii in range(len(stats)):
# (Pdb) c
# > /Users/dorafohring/Desktop/git/imaka/imaka/analysis/plot_stats.py(898)plot_all_profiles()
# -> pdb.set_trace()
# (Pdb) c
# > /Users/dorafohring/Desktop/git/imaka/imaka/analysis/plot_stats.py(899)plot_all_profiles()
# -> for ii in range(len(stats)):
# (Pdb) c
# > /Users/dorafohring/Desktop/git/imaka/imaka/analysis/plot_stats.py(898)plot_all_profiles()
# -> pdb.set_trace()
# (Pdb) c
# > /Users/dorafohring/Desktop/git/imaka/imaka/analysis/plot_stats.py(953)plot_all_profiles()
# -> return

# %%
plot_stats.plot_profile(['20170110'], suffixes=['open', 'closed'], root_dir=stats_dir)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-2a8ca31581e2> in <module>()
# ----> 1 plot_stats.plot_profile(['20170110'], suffixes=['open', 'closed'], root_dir=stats_dir)
#
# /Users/dorafohring/Desktop/git/imaka/imaka/analysis/plot_stats.py in plot_profile(date, suffixes, out_suffix, root_dir)
#     819     plt.rcParams.update(latexParams)
#     820
# --> 821     stats_dir = root_dir + date + '/fli/reduce/stats/'
#     822     plots_dir = root_dir + date + '/fli/reduce/plots/'
#     823
#
# TypeError: must be str, not list

# %%
plot_stats.plot_profile('20170111', root_dir=stats_dir)

# %%
plot_stats.plot_profile('20170113', suffixes=['open1', 'open2','closed1', 'closed2', 'ttf1', 'ttf2'], root_dir=stats_dir)

# %%
plot_stats.plot_profile('20170214', suffixes=['open', 'tt','closed'], root_dir=stats_dir)

# %%
plot_stats.plot_profile('20170215', suffixes=['open', 'tt','closeda', 'closedb', 'closedc', 'closede'], root_dir=stats_dir)

# %%
plot_stats.plot_profile('20170216', suffixes=['open', 'tt','closeda', 'closedb', 'closedc', 'closede', 'closedf', 'closedg', 'closedh', 'closedi'], root_dir=stats_dir)

# %%
plot_stats.plot_profile('20170217', suffixes=['open','closeda', 'closedb', 'closedc', 'closedf'], root_dir=stats_dir) # no e

# %%
plot_stats.plot_profile('20170517', suffixes=['open','closedA', 'closedB', 'closed', 'stacks'], root_dir=stats_dir)

# %%
plot_stats.plot_profile('20170518', suffixes=['open','closedA', 'closedB', 'closed', 'stacks'], root_dir=stats_dir)

# %%
plot_stats.plot_profile('20170519', suffixes=['open','closedA', 'closedB', 'closed', 'stacks'], root_dir=stats_dir)

# %%
plot_stats.plot_profile('20170520', suffixes=['open','closedA', 'closedD'], root_dir=stats_dir)

# %%
plot_stats.plot_profile('20170521', suffixes=['open','closedA', 'closed', 'stacks'], root_dir=stats_dir)

# %% [markdown]
# Average over all nights

# %%
plot_stats.plot_all_profiles(['20170109', '20170110', '20170111', '20170113', '20170214', '20170215','20170216', '20170217', '20170517', '20170518', '20170519', '20170520', '20170521' ], stats_dir)
