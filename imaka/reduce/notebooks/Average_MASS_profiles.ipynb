# %% [markdown]
# # Average MASS profiles

# %%
from imaka.analysis import plot_stats
from imaka.reduce import massdimm

# %%
UT_date = '20170521'
massdimm_dir = '/Users/dorafohring/Desktop/imaka/massdimm/'
stats_dir = '/Users/dorafohring/Desktop/imaka/data/'

# %% [markdown]
# Get stats FITS tables

# %%
plot_stats.fetch_stats_from_onaga([UT_date], output_root=stats_dir)
# Out:
# imaka@onaga.ifa.hawaii.edu:/Volumes/DATA4/imaka/20170521/fli/reduce/stats/stats*.fits
# /Users/dorafohring/Desktop/imaka/data//20170521/fli/reduce/stats/

# %% [markdown]
# Get MASS/DIMM files

# %%
save_suffixes = ['open','closedA', 'closed', 'stacks']

# %%
massdimm.fetch_data(utDate=UT_date, saveTo=massdimm_dir)
for suffix in save_suffixes:
    massdimm.append_mass_dimm(stats_dir + '{0}/fli/reduce/stats/stats_{1}.fits'.format(UT_date, suffix), massdimm_dir)
# Out:
# Saving MASS/DIMM data to directory:
# /Users/dorafohring/Desktop/imaka/massdimm/

# %% [markdown]
# Plots:

# %% [markdown]
# 20170109

# %%
plot_stats.plot_all_profiles(['20170109'], root_dir=stats_dir)

# %% [markdown]
# 20170110

# %%
plot_stats.plot_all_profiles(['20170110'], root_dir=stats_dir)

# %% [markdown]
# 20170111

# %%
plot_stats.plot_all_profiles(['20170111'], root_dir=stats_dir)

# %% [markdown]
# 20170113

# %%
plot_stats.plot_all_profiles(['20170113'], root_dir=stats_dir)

# %% [markdown]
# 20170214

# %%
plot_stats.plot_all_profiles(['20170214'], root_dir=stats_dir)

# %% [markdown]
# 20170215

# %%
plot_stats.plot_all_profiles(['20170215'], root_dir=stats_dir)

# %% [markdown]
# 20170216

# %%
plot_stats.plot_all_profiles(['20170216'], root_dir=stats_dir)

# %% [markdown]
# 20170217

# %%
plot_stats.plot_all_profiles(['20170217'], root_dir=stats_dir)

# %% [markdown]
# 20170517

# %%
plot_stats.plot_all_profiles(['20170517'], root_dir=stats_dir)

# %% [markdown]
# 20170518

# %%
plot_stats.plot_all_profiles(['20170518'], root_dir=stats_dir)

# %% [markdown]
# 20170519

# %%
plot_stats.plot_all_profiles(['20170519'], root_dir=stats_dir)

# %% [markdown]
# 20170520

# %%
plot_stats.plot_all_profiles(['20170520'], root_dir=stats_dir)

# %% [markdown]
# 20170521

# %%
plot_stats.plot_all_profiles(['20170521'], root_dir=stats_dir)

# %% [markdown]
# Average over all nights

# %%
plot_stats.plot_all_profiles(['20170109', '20170110', '20170111', '20170113', '20170214', '20170215','20170216', '20170217', '20170517', '20170518', '20170519', '20170520', '20170521' ], stats_dir)
