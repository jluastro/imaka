# %% [markdown]
# # 20220123 Initial Analysis

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import matplotlib.pyplot as plt
from astropy.table import Table
from astropy.io import fits
import numpy as np
from importlib import reload
from imaka.analysis import plot_stats
from imaka.analysis import plot_redu
from imaka.reduce import util
from astropy.stats import sigma_clipped_stats

## Edit Me
from imaka.reduce.nights import reduce_2022_01_23 as redu
night = '20220123'
fld = 'Beehive-W'

root_dir = redu.root_dir
stats_dir = root_dir + "reduce/stats/"
plots_dir = root_dir + "reduce/plots/"
stack_dir = root_dir + "reduce/stacks/"
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
## Had an issue with stacking, the gfol
for key in list(redu.dict_images.keys()):
    for i in range(len(redu.dict_images[key])):
        img_num = redu.dict_images[key]
        suf = redu.dict_suffix[key]
        test_img_base = 'sta{img:03d}{suf:s}_scan'.format(img=img_num[i], suf=suf)
        
        stars = Table.read(root_dir + f'reduce/{fld}/' + test_img_base + '_clean_stars_stats_mdp.fits')
        print(f"key: {key} image {img_num[i]} stars: {len(stars)}")
# Out:
# key: LS_5wfs_1 image 0 stars: 35
# key: LS_5wfs_1 image 4 stars: 30
# key: LS_5wfs_1 image 8 stars: 34
# key: LS_5wfs_1 image 12 stars: 32
# key: LS_5wfs_1 image 16 stars: 31
# key: LS_5wfs_1 image 20 stars: 33
# key: LS_5wfs_1 image 24 stars: 38
# key: LS_5wfs_1 image 28 stars: 37
# key: LS_5wfs_1 image 32 stars: 51
# key: LS_5wfs_1 image 36 stars: 131
# key: LS_5wfs_1 image 40 stars: 71
# key: LS_5wfs_1 image 44 stars: 76
# key: LS_3wfs_s_1 image 1 stars: 36
# key: LS_3wfs_s_1 image 5 stars: 48
# key: LS_3wfs_s_1 image 9 stars: 38
# key: LS_3wfs_s_1 image 13 stars: 25
# key: LS_3wfs_s_1 image 17 stars: 33
# key: LS_3wfs_s_1 image 21 stars: 38
# key: LS_3wfs_s_1 image 25 stars: 34
# key: LS_3wfs_s_1 image 29 stars: 43
# key: LS_3wfs_s_1 image 33 stars: 75
# key: LS_3wfs_s_1 image 37 stars: 94
# key: LS_3wfs_s_1 image 41 stars: 69
# key: LS_3wfs_s_1 image 45 stars: 58
# key: LS_3wfs_w_1 image 2 stars: 37
# key: LS_3wfs_w_1 image 6 stars: 36
# key: LS_3wfs_w_1 image 10 stars: 36
# key: LS_3wfs_w_1 image 14 stars: 25
# key: LS_3wfs_w_1 image 18 stars: 31
# key: LS_3wfs_w_1 image 22 stars: 33
# key: LS_3wfs_w_1 image 26 stars: 32
# key: LS_3wfs_w_1 image 30 stars: 43
# key: LS_3wfs_w_1 image 34 stars: 77
# key: LS_3wfs_w_1 image 38 stars: 114
# key: LS_3wfs_w_1 image 42 stars: 67
# key: LS_3wfs_w_1 image 46 stars: 67
# key: open_1 image 3 stars: 25
# key: open_1 image 7 stars: 33
# key: open_1 image 11 stars: 22
# key: open_1 image 15 stars: 21
# key: open_1 image 19 stars: 24
# key: open_1 image 23 stars: 28
# key: open_1 image 27 stars: 37
# key: open_1 image 31 stars: 40
# key: open_1 image 35 stars: 62
# key: open_1 image 39 stars: 57
# key: open_1 image 43 stars: 75
# key: open_1 image 47 stars: 37
# key: LS_5wfs_2 image 58 stars: 169
# key: LS_5wfs_2 image 62 stars: 186
# key: LS_5wfs_2 image 66 stars: 153
# key: LS_5wfs_2 image 70 stars: 209
# key: LS_5wfs_2 image 74 stars: 151
# key: LS_5wfs_2 image 78 stars: 172
# key: LS_5wfs_2 image 82 stars: 172
# key: LS_5wfs_2 image 86 stars: 169
# key: LS_5wfs_2 image 90 stars: 160
# key: LS_5wfs_2 image 94 stars: 135
# key: LS_5wfs_2 image 98 stars: 159
# key: LS_3wfs_s_2 image 59 stars: 154
# key: LS_3wfs_s_2 image 63 stars: 176
# key: LS_3wfs_s_2 image 67 stars: 141
# key: LS_3wfs_s_2 image 71 stars: 161
# key: LS_3wfs_s_2 image 75 stars: 203
# key: LS_3wfs_s_2 image 79 stars: 139
# key: LS_3wfs_s_2 image 83 stars: 173
# key: LS_3wfs_s_2 image 87 stars: 194
# key: LS_3wfs_s_2 image 91 stars: 174
# key: LS_3wfs_s_2 image 95 stars: 174
# key: LS_3wfs_s_2 image 99 stars: 164
# key: LS_3wfs_w_2 image 60 stars: 159
# key: LS_3wfs_w_2 image 64 stars: 179
# key: LS_3wfs_w_2 image 68 stars: 162
# key: LS_3wfs_w_2 image 72 stars: 178
# key: LS_3wfs_w_2 image 76 stars: 151
# key: LS_3wfs_w_2 image 80 stars: 153
# key: LS_3wfs_w_2 image 84 stars: 175
# key: LS_3wfs_w_2 image 88 stars: 147
# key: LS_3wfs_w_2 image 92 stars: 173
# key: LS_3wfs_w_2 image 96 stars: 164
# key: LS_3wfs_w_2 image 100 stars: 171
# key: open_2 image 61 stars: 99
# key: open_2 image 65 stars: 133
# key: open_2 image 69 stars: 129
# key: open_2 image 73 stars: 139
# key: open_2 image 77 stars: 131
# key: open_2 image 81 stars: 125
# key: open_2 image 85 stars: 126
# key: open_2 image 89 stars: 133
# key: open_2 image 93 stars: 151
# key: open_2 image 97 stars: 138
# key: open_2 image 101 stars: 145

# %% [markdown]
# ## Reduction inputs

# %%
## sky, flats, and mask
sky_f = redu.sky_dir + "beehive_sky.fits"
flat_f = redu.calib_dir + "domeflat.fits"
mask_f = redu.calib_dir + "domemask.fits"

fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(20,7))
fig.suptitle(night + ' Calibration inputs')

ax0.set_title('sky')
image_data = fits.getdata(sky_f)
ax0.imshow(image_data, cmap='gray', vmin=0, vmax=1000, origin='lower')

ax1.set_title('flat')
image_data = fits.getdata(flat_f)
ax1.imshow(image_data, cmap='gray', vmin=0, vmax=1.5, origin='lower')

ax2.set_title('mask')
image_data = fits.getdata(mask_f)
ax2.imshow(image_data, cmap='gray', vmin=0, vmax=1, origin='lower')

plt.show()

# %%
# sky comparison
sky_f = redu.sky_dir + "beehive_sky.fits"
sky_f1 = redu.sky_dir + "beehive_sky1.fits"
sky_f2 = redu.sky_dir + "beehive_sky2.fits"

fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(20,7))
fig.suptitle(night + ' Sky Comparison')

ax0.set_title('sky')
image_data = fits.getdata(sky_f)
ax0.imshow(image_data, cmap='gray', vmin=0, vmax=1000, origin='lower')

ax1.set_title('sky1')
image_data = fits.getdata(sky_f1)
ax1.imshow(image_data, cmap='gray', vmin=0, vmax=1000, origin='lower')

ax2.set_title('sky2')
image_data = fits.getdata(sky_f2)
ax2.imshow(image_data, cmap='gray', vmin=0, vmax=1000, origin='lower')

plt.show()

# %% [markdown]
# ## Real time plots

# %% [markdown]
# Play with a star list and look at trends in FWHM, etc.

# %%
# Enter chosen file
test_img_base = 'sta009n3wfs_c_scan' # this is the test single code

# %%
# pick a file based on key
key = 'LS_3wfs_s_2' #'open_2' 
i=6

img_num = redu.dict_images[key]
suf = redu.dict_suffix[key]
test_img_base = 'sta{img:03d}{suf:s}_scan'.format(img=img_num[i], suf=suf)

# %%
plot_redu.plot_ee_50(test_img_base, root_dir, fld, night)
# Out:
# 50% EE radius = 0.300"

# %%
plot_redu.plot_starlist_stats(test_img_base, root_dir, fld, night)
# Out:
# x: fwhm_x_avg = 0.52" fwhm_x_med = 0.54" fwhm_x_std = 0.12"
# x: fwhm_x_avg = 0.52" fwhm_x_med = 0.54" fwhm_x_std = 0.12"

# %% [markdown]
# ## Night-Long Stats

# %%
stats = Table.read(root_dir + 'reduce/stats/stats_LS_5wfs_2.fits')

# %%
# stats by star 
stats_c = Table.read(root_dir + 'reduce/stats/stats_LS_5wfs_2.fits')
stats_o = Table.read(root_dir + 'reduce/stats/stats_open_2.fits')

# stats by stack? => doesn't work
#stats_c = Table.read(root_dir + 'reduce/stacks/fld2_stack_LS_c_stars_stats_mdp.fits')
#stats_o = Table.read(root_dir + 'reduce/stacks/fld2_stack__o_stars_stats.fits')

print(stats.colnames)

plt.figure(figsize=(10,10))
plt.clf()
plt.errorbar(stats_c['Minor Alpha'], stats_c['Beta'], xerr=stats_c['Minor Alpha std'], yerr=stats_c['Beta std'], fmt='r.', label='Closed (LS)')
plt.errorbar(stats_o['Minor Alpha'], stats_o['Beta'], xerr=stats_o['Minor Alpha std'], yerr=stats_o['Beta std'], fmt='k.', label='Open')
plt.xlabel(r'Minor $\alpha$')
plt.ylabel(r'$\beta$')
plt.legend()

plt.figure(figsize=(10,10))
plt.clf()
plt.errorbar(stats_c['Phi'], stats_c['Beta'], xerr=stats_c['Phi std'], yerr=stats_c['Beta std'], fmt='r.', label='Closed (LS)')
plt.errorbar(stats_o['Phi'], stats_o['Beta'], xerr=stats_o['Phi std'], yerr=stats_o['Beta std'], fmt='k.', label='Open')
plt.xlabel(r'$\phi$')
plt.ylabel(r'$\beta$')
plt.legend()
# Out:
# ['Image', 'FILTER', 'BINFAC', 'DATE_UTC', 'TIME_UTC', 'DATE_HST', 'TIME_HST', 'FWHM', 'FWHM_std', 'EE25', 'EE50', 'EE80', 'NEA', 'NEA2', 'xFWHM', 'yFWHM', 'theta', 'emp_fwhm', 'emp_fwhm_std', 'quadrant', 'Index', 'N Stars', 'N Sky', 'N Sky std', 'Amplitude', 'Amplitude std', 'Phi', 'Phi std', 'Beta', 'Beta std', 'Minor Alpha', 'Minor Alpha std', 'Major Alpha', 'Major Alpha std']

# %% [markdown]
# ## Star STATS

# %%
suffixes = list(redu.dict_suffix.keys())
suffixes
# Out:
# ['LS_3wfs_s_1',
#  'LS_3wfs_w_1',
#  'LS_5wfs_1',
#  'open_1',
#  'LS_3wfs_s_2',
#  'LS_3wfs_w_2',
#  'LS_5wfs_2',
#  'open_2']

# %%
suffixes = ['open_1', 'LS_3wfs_s_1', 'LS_3wfs_w_1', 'LS_5wfs_1']
plot_stats.plot_stack_stats(night, suffixes=suffixes, root_dir=root_dir + '../../', reduce_dir='sta/reduce/')

# %%
suffixes = ['open_2', 'LS_3wfs_s_2', 'LS_3wfs_w_2', 'LS_5wfs_2']
plot_stats.plot_stack_stats(night, suffixes=suffixes, root_dir=root_dir + '../../', reduce_dir='sta/reduce/')

# %% [markdown]
# # Time Variation w/MASS-DIMM

# %%
open_file = stats_dir +"stats_open_1_mdp.fits"
closed_file2 = stats_dir+ "stats_LS_5wfs_1_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file2, 'emp_fwhm', "2022-01-23: FWHM and Seeing over time with Closed {5wfs}, first half", plots_dir)

# %%
open_file = stats_dir +"stats_open_2_mdp.fits"
closed_file2 = stats_dir+ "stats_LS_5wfs_2_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file2, 'emp_fwhm', "2022-01-23: FWHM and Seeing over time with Closed {5wfs}, second half", plots_dir)

# %%
open_file = stats_dir +"stats_open_1_mdp.fits"
closed_file1 = stats_dir+ "stats_LS_3wfs_w_1_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file1, 'emp_fwhm', "2022-01-23: FWHM and Seeing over time with Closed {3wfs wide}, first half", plots_dir)

# %%
open_file = stats_dir +"stats_open_2_mdp.fits"
closed_file1 = stats_dir+ "stats_LS_3wfs_w_2_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file1, 'emp_fwhm', "2022-01-23: FWHM and Seeing over time with Closed {3wfs wide}, second half", plots_dir)

# %%
open_file = stats_dir +"stats_open_1_mdp.fits"
closed_file1 = stats_dir+ "stats_LS_3wfs_s_1_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file1, 'emp_fwhm', "2022-01-23: FWHM and Seeing over time with Closed {3wfs small}, first half", plots_dir)

# %%
open_file = stats_dir +"stats_open_2_mdp.fits"
closed_file1 = stats_dir+ "stats_LS_3wfs_s_2_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file1, 'emp_fwhm', "2022-01-23: FWHM and Seeing over time with Closed {3wfs small}, second half", plots_dir)

# %% [markdown]
# # Aggregate Plots

# %%
suffixes = ['open_1', 'LS_3wfs_s_1', 'LS_3wfs_w_1', 'LS_5wfs_1']
files = [stats_dir + 'stats_' + suffix + '_mdp.fits' for suffix in suffixes]
print(files)
colors = ['red', 'orange', 'green', 'blue', 'lightgreen', 'cyan']
plot_stats.comp_cdf(files, suffixes, colors)
# Out:
# ['/g/lu/data/imaka/onaga/20220123/sta/reduce/stats/stats_open_1_mdp.fits', '/g/lu/data/imaka/onaga/20220123/sta/reduce/stats/stats_LS_3wfs_s_1_mdp.fits', '/g/lu/data/imaka/onaga/20220123/sta/reduce/stats/stats_LS_3wfs_w_1_mdp.fits', '/g/lu/data/imaka/onaga/20220123/sta/reduce/stats/stats_LS_5wfs_1_mdp.fits']

# %%
suffixes = ['open_2', 'LS_3wfs_s_2', 'LS_3wfs_w_2', 'LS_5wfs_2']
files = [stats_dir + 'stats_' + suffix + '_mdp.fits' for suffix in suffixes]
print(files)
colors = ['red', 'orange', 'green', 'blue', 'lightgreen', 'cyan']
plot_stats.comp_cdf(files, suffixes, colors)
# Out:
# ['/g/lu/data/imaka/onaga/20220123/sta/reduce/stats/stats_open_2_mdp.fits', '/g/lu/data/imaka/onaga/20220123/sta/reduce/stats/stats_LS_3wfs_s_2_mdp.fits', '/g/lu/data/imaka/onaga/20220123/sta/reduce/stats/stats_LS_3wfs_w_2_mdp.fits', '/g/lu/data/imaka/onaga/20220123/sta/reduce/stats/stats_LS_5wfs_2_mdp.fits']

# %% [markdown]
# # Field Variability

# %% [markdown]
# ## Closed loop, single exposure

# %%
from importlib import reload
reload(plot_stats)
print(test_img_base)
img_file = root_dir + f'reduce/{fld}/{test_img_base}_clean.fits'
starlist = root_dir +  f'reduce/{fld}/{test_img_base}_clean_stars_stats_mdp.fits'
plot_stats.plot_var(img_file, starlist, "SINGLE: Closed 5wfs(LS)")
# Out:
# sta083n3wfs_c_scan
# Median FWHM           = 0.437"
# Median FWHM (clipped) = 0.437"
# Mean FWHM             = 0.441"
# Mean FWHM (clipped)   = 0.396"
# Stddev FWHM           = 0.399"
# Stddev FWHM (clipped) = 0.212"

# %%
from importlib import reload
reload(plot_stats)
print(test_img_base)
img_file = root_dir + f'reduce/{fld}/{test_img_base}_clean.fits'
starlist = root_dir +  f'reduce/{fld}/{test_img_base}_clean_stars_stats_mdp.fits'
plot_stats.plot_var(img_file, starlist, "SINGLE: Open")
# Out:
# sta085_o_scan
# Median FWHM           = 0.768"
# Median FWHM (clipped) = 0.768"
# Mean FWHM             = 0.627"
# Mean FWHM (clipped)   = 0.605"
# Stddev FWHM           = 0.396"
# Stddev FWHM (clipped) = 0.319"

# %% [markdown]
# ### Open Loop

# %%
img_file = stack_dir + 'beehive_stack__o.fits' 
starlist = stack_dir + 'beehive_stack__o_stars_stats_mdp.fits'
plot_stats.plot_var(img_file, starlist, "STACK: Open")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-55c263af225b> in <module>
#       1 img_file = stack_dir + 'beehive_stack__o.fits'
#       2 starlist = stack_dir + 'beehive_stack__o_stars_stats_mdp.fits'
# ----> 3 plot_stats.plot_var(img_file, starlist, "STACK: Open")
#
# ~/code/imaka/imaka/analysis/plot_stats.py in plot_var(img_file, starlist, title)
#    1901         stars = Table.read(starlist, format='ascii')
#    1902     else:
# -> 1903         stars = Table.read(starlist)
#    1904
#    1905     # Check to see if we have already calculated Moffat parameters.
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/connect.py in __call__(self, *args, **kwargs)
#      59         descriptions = kwargs.pop('descriptions', None)
#      60
# ---> 61         out = registry.read(cls, *args, **kwargs)
#      62
#      63         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/registry.py in read(cls, format, cache, *args, **kwargs)
#     503                     try:
#     504                         ctx = get_readable_fileobj(args[0], encoding='binary', cache=cache)
# --> 505                         fileobj = ctx.__enter__()
#     506                     except OSError:
#     507                         raise
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers)
#     250                 timeout=remote_timeout, sources=sources,
#     251                 http_headers=http_headers)
# --> 252         fileobj = io.FileIO(name_or_obj, 'r')
#     253         if is_url and not cache:
#     254             delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/lu/data/imaka/onaga/20220123/sta/reduce/stacks/beehive_stack__o_stars_stats_mdp.fits'

# %% [markdown]
# ### Closed loop (3wfs_s)

# %%
img_file = stack_dir + 'beehive_stack_n3wfs_c.fits' 
starlist = stack_dir + 'beehive_stack_n3wfs_c_stars_stats_mdp.fits'
plot_stats.plot_var(img_file, starlist, "STACK: Closed (3wfs_s)")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-7ace5a337ac9> in <module>
#       1 img_file = stack_dir + 'beehive_stack_n3wfs_c.fits'
#       2 starlist = stack_dir + 'beehive_stack_n3wfs_c_stars_stats_mdp.fits'
# ----> 3 plot_stats.plot_var(img_file, starlist, "STACK: Closed (3wfs_s)")
#
# ~/code/imaka/imaka/analysis/plot_stats.py in plot_var(img_file, starlist, title)
#    1901         stars = Table.read(starlist, format='ascii')
#    1902     else:
# -> 1903         stars = Table.read(starlist)
#    1904
#    1905     # Check to see if we have already calculated Moffat parameters.
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/connect.py in __call__(self, *args, **kwargs)
#      59         descriptions = kwargs.pop('descriptions', None)
#      60
# ---> 61         out = registry.read(cls, *args, **kwargs)
#      62
#      63         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/registry.py in read(cls, format, cache, *args, **kwargs)
#     503                     try:
#     504                         ctx = get_readable_fileobj(args[0], encoding='binary', cache=cache)
# --> 505                         fileobj = ctx.__enter__()
#     506                     except OSError:
#     507                         raise
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers)
#     250                 timeout=remote_timeout, sources=sources,
#     251                 http_headers=http_headers)
# --> 252         fileobj = io.FileIO(name_or_obj, 'r')
#     253         if is_url and not cache:
#     254             delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/lu/data/imaka/onaga/20220123/sta/reduce/stacks/beehive_stack_n3wfs_c_stars_stats_mdp.fits'

# %% [markdown]
# ### Closed loop (3wfs_w)

# %%
img_file = stack_dir + 'beehive_stack_n3wide_c.fits' 
starlist = stack_dir + 'beehive_stack_n3wide_c_stars_stats_mdp.fits'
plot_stats.plot_var(img_file, starlist, "STACK: Closed (3wfs_wide)")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-73a16158a455> in <module>
#       1 img_file = stack_dir + 'beehive_stack_n3wide_c.fits'
#       2 starlist = stack_dir + 'beehive_stack_n3wide_c_stars_stats_mdp.fits'
# ----> 3 plot_stats.plot_var(img_file, starlist, "STACK: Closed (3wfs_wide)")
#
# ~/code/imaka/imaka/analysis/plot_stats.py in plot_var(img_file, starlist, title)
#    1901         stars = Table.read(starlist, format='ascii')
#    1902     else:
# -> 1903         stars = Table.read(starlist)
#    1904
#    1905     # Check to see if we have already calculated Moffat parameters.
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/connect.py in __call__(self, *args, **kwargs)
#      59         descriptions = kwargs.pop('descriptions', None)
#      60
# ---> 61         out = registry.read(cls, *args, **kwargs)
#      62
#      63         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/registry.py in read(cls, format, cache, *args, **kwargs)
#     503                     try:
#     504                         ctx = get_readable_fileobj(args[0], encoding='binary', cache=cache)
# --> 505                         fileobj = ctx.__enter__()
#     506                     except OSError:
#     507                         raise
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers)
#     250                 timeout=remote_timeout, sources=sources,
#     251                 http_headers=http_headers)
# --> 252         fileobj = io.FileIO(name_or_obj, 'r')
#     253         if is_url and not cache:
#     254             delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/lu/data/imaka/onaga/20220123/sta/reduce/stacks/beehive_stack_n3wide_c_stars_stats_mdp.fits'

# %% [markdown]
# ### Closed loop (5wfs)

# %%
img_file = stack_dir + 'beehive_stack_n5wfs_c.fits'
starlist = stack_dir + 'beehive_stack_n5wfs_c_stars_stats_mdp.fits'
plot_stats.plot_var(img_file, starlist, "STACK: Closed (5wfs)")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-25384f43f315> in <module>
#       1 img_file = stack_dir + 'beehive_stack_n5wfs_c.fits'
#       2 starlist = stack_dir + 'beehive_stack_n5wfs_c_stars_stats_mdp.fits'
# ----> 3 plot_stats.plot_var(img_file, starlist, "STACK: Closed (5wfs)")
#
# ~/code/imaka/imaka/analysis/plot_stats.py in plot_var(img_file, starlist, title)
#    1901         stars = Table.read(starlist, format='ascii')
#    1902     else:
# -> 1903         stars = Table.read(starlist)
#    1904
#    1905     # Check to see if we have already calculated Moffat parameters.
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/connect.py in __call__(self, *args, **kwargs)
#      59         descriptions = kwargs.pop('descriptions', None)
#      60
# ---> 61         out = registry.read(cls, *args, **kwargs)
#      62
#      63         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/registry.py in read(cls, format, cache, *args, **kwargs)
#     503                     try:
#     504                         ctx = get_readable_fileobj(args[0], encoding='binary', cache=cache)
# --> 505                         fileobj = ctx.__enter__()
#     506                     except OSError:
#     507                         raise
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers)
#     250                 timeout=remote_timeout, sources=sources,
#     251                 http_headers=http_headers)
# --> 252         fileobj = io.FileIO(name_or_obj, 'r')
#     253         if is_url and not cache:
#     254             delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/lu/data/imaka/onaga/20220123/sta/reduce/stacks/beehive_stack_n5wfs_c_stars_stats_mdp.fits'
