# %% [markdown]
# # 20220123 Initial Analysis

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import matplotlib.pyplot as plt
from astropy.table import Table
from astropy.io import fits
import numpy as np
from importlib import reload
from imaka.analysis import plot_stats
from imaka.reduce import util
from astropy.stats import sigma_clipped_stats

## Edit Me
from imaka.reduce.nights import reduce_2022_01_23 as redu
night = '20220123'
fld = 'Beehive-W'

root_dir = redu.root_dir
stats_dir = root_dir + "reduce/stats/"
plots_dir = root_dir + "reduce/plots/"
stack_dir = root_dir + "reduce/stacks/"
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
## sky
sky_f = "/g/lu/data/imaka/onaga/20220123/sta/reduce/sky/beehive_sky.fits"
image_data = fits.getdata(sky_f)

plt.figure(figsize=(11,10))
plt.title('Total Sky')
plt.imshow(image_data, cmap='gray', vmin=0, vmax=1000, origin='lower')
plt.colorbar()
plt.show()

# %%
## sky
sky_f = "/g/lu/data/imaka/onaga/20220122/sta/reduce/sky/beehive_sky1.fits"
image_data = fits.getdata(sky_f)

plt.figure(figsize=(11,10))
plt.title('Middle of the night sky')
plt.imshow(image_data, cmap='gray', vmin=0, vmax=1000, origin='lower')
plt.colorbar()
plt.show()

# %%
## sky
sky_f = "/g/lu/data/imaka/onaga/20220122/sta/reduce/sky/beehive_sky2.fits"
image_data = fits.getdata(sky_f)

plt.figure(figsize=(11,10))
plt.title('End of the night sky')
plt.imshow(image_data, cmap='gray', vmin=0, vmax=1000, origin='lower')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Real time plots

# %%
test_img_base = 'sta008n5wfs_c_scan'

img, hdr = fits.getdata(root_dir + f'reduce/{fld}/' + test_img_base + '_clean.fits', header=True)
scale = util.get_plate_scale(img, hdr)


from astropy.table import Table
ee = Table.read(root_dir + f'reduce/{fld}/ee/' + test_img_base + '_clean_ee.txt', format='ascii')

plt.plot(ee['Radius'], ee['EE'])
plt.xlabel('Radius (arcsec)')
plt.ylabel('Encircled Energy')

fdx = np.where(ee['EE'] < 0.5)[0][-1]
fwhm = ee['Radius'][fdx]

plt.axhline(0.5, alpha=0.5)
plt.axvline(fwhm, ls ='--',alpha=0.5)
plt.title(f"EE for {night}, {test_img_base} \n 50% EE radius = {fwhm:.3f}")


print(f'50% EE radius = {fwhm:.3f}"')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-12cae5ea0e33> in <module>
#       6
#       7 from astropy.table import Table
# ----> 8 ee = Table.read(root_dir + f'reduce/{fld}/ee/' + test_img_base + '_clean_ee.txt', format='ascii')
#       9
#      10 plt.plot(ee['Radius'], ee['EE'])
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/connect.py in __call__(self, *args, **kwargs)
#      59         descriptions = kwargs.pop('descriptions', None)
#      60
# ---> 61         out = registry.read(cls, *args, **kwargs)
#      62
#      63         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/registry.py in read(cls, format, cache, *args, **kwargs)
#     518
#     519         reader = get_reader(format, cls)
# --> 520         data = reader(*args, **kwargs)
#     521
#     522         if not isinstance(data, cls):
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/connect.py in io_read(format, filename, **kwargs)
#      16         format = re.sub(r'^ascii\.', '', format)
#      17         kwargs['format'] = format
# ---> 18     return read(filename, **kwargs)
#      19
#      20
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/ui.py in read(table, guess, **kwargs)
#     338         # through below to the non-guess way so that any problems result in a
#     339         # more useful traceback.
# --> 340         dat = _guess(table, new_kwargs, format, fast_reader)
#     341         if dat is None:
#     342             guess = False
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/ui.py in _guess(table, read_kwargs, format, fast_reader)
#     498
#     499             reader.guessing = True
# --> 500             dat = reader.read(table)
#     501             _read_trace.append({'kwargs': copy.deepcopy(guess_kwargs),
#     502                                 'Reader': reader.__class__,
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/core.py in read(self, table)
#    1263
#    1264         # Get a list of the lines (rows) in the table
# -> 1265         self.lines = self.inputter.get_lines(table, newline=newline)
#    1266
#    1267         # Set self.data.data_lines to a slice of lines contain the data rows
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/core.py in get_lines(self, table, newline)
#     304                     or ('\n' not in table + '' and '\r' not in table + '')):
#     305                 with get_readable_fileobj(table,
# --> 306                                           encoding=self.encoding) as fileobj:
#     307                     table = fileobj.read()
#     308             if newline is None:
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers)
#     250                 timeout=remote_timeout, sources=sources,
#     251                 http_headers=http_headers)
# --> 252         fileobj = io.FileIO(name_or_obj, 'r')
#     253         if is_url and not cache:
#     254             delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/lu/data/imaka/onaga/20220123/sta/reduce/Beehive-W/ee/sta008n5wfs_c_scan_clean_ee.txt'

# %% [markdown]
# Play with a star list and look at trends in FWHM, etc.

# %%
stars = Table.read(root_dir + f'reduce/{fld}/' + test_img_base + '_clean_stars.txt', format='ascii')

# Get the plate scale
img, hdr = fits.getdata(root_dir + f'{fld}/' + test_img_base + '.fits', header=True)
scale = util.get_plate_scale(img, hdr)
del img
del hdr

plt.figure()
plt.plot(stars['mag'], stars['x_fwhm'] * scale, 'r.', label='X', alpha=0.5)
plt.plot(stars['mag'], stars['y_fwhm'] * scale, 'b.', label='Y', alpha=0.5)
plt.xlabel('Mag')
plt.ylabel('FWHM (")')
plt.legend()
plt.ylim(0, 1.5)
plt.title(test_img_base)

plt.figure()
r = np.hypot(stars['xcentroid'] - (stars['xcentroid'].max() / 2.0), 
             stars['ycentroid'] - (stars['ycentroid'].max() / 2.0)) * scale / 60.0
plt.plot(r, stars['x_fwhm'] * scale, 'r.', label='X', alpha=0.5)
plt.plot(r, stars['y_fwhm'] * scale, 'b.', label='Y', alpha=0.5)
plt.xlabel('Radius (amin)')
plt.ylabel('FWHM (")')
plt.legend()
plt.ylim(0, 1.5)
plt.title(test_img_base)

fwhm_x_avg, fwhm_x_med, fwhm_x_std = sigma_clipped_stats(stars['x_fwhm'] * scale)
fwhm_y_avg, fwhm_y_med, fwhm_y_std = sigma_clipped_stats(stars['y_fwhm'] * scale)
print(f'x: fwhm_x_avg = {fwhm_x_avg:.2f}" fwhm_x_med = {fwhm_x_med:.2f}" fwhm_x_std = {fwhm_x_std:.2f}"')
print(f'x: fwhm_x_avg = {fwhm_x_avg:.2f}" fwhm_x_med = {fwhm_x_med:.2f}" fwhm_x_std = {fwhm_x_std:.2f}"')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-04a9796b3fbd> in <module>
# ----> 1 stars = Table.read(root_dir + f'reduce/{fld}/' + test_img_base + '_clean_stars.txt', format='ascii')
#       2
#       3 # Get the plate scale
#       4 img, hdr = fits.getdata(root_dir + f'{fld}/' + test_img_base + '.fits', header=True)
#       5 scale = util.get_plate_scale(img, hdr)
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/connect.py in __call__(self, *args, **kwargs)
#      59         descriptions = kwargs.pop('descriptions', None)
#      60
# ---> 61         out = registry.read(cls, *args, **kwargs)
#      62
#      63         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/registry.py in read(cls, format, cache, *args, **kwargs)
#     518
#     519         reader = get_reader(format, cls)
# --> 520         data = reader(*args, **kwargs)
#     521
#     522         if not isinstance(data, cls):
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/connect.py in io_read(format, filename, **kwargs)
#      16         format = re.sub(r'^ascii\.', '', format)
#      17         kwargs['format'] = format
# ---> 18     return read(filename, **kwargs)
#      19
#      20
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/ui.py in read(table, guess, **kwargs)
#     338         # through below to the non-guess way so that any problems result in a
#     339         # more useful traceback.
# --> 340         dat = _guess(table, new_kwargs, format, fast_reader)
#     341         if dat is None:
#     342             guess = False
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/ui.py in _guess(table, read_kwargs, format, fast_reader)
#     498
#     499             reader.guessing = True
# --> 500             dat = reader.read(table)
#     501             _read_trace.append({'kwargs': copy.deepcopy(guess_kwargs),
#     502                                 'Reader': reader.__class__,
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/core.py in read(self, table)
#    1263
#    1264         # Get a list of the lines (rows) in the table
# -> 1265         self.lines = self.inputter.get_lines(table, newline=newline)
#    1266
#    1267         # Set self.data.data_lines to a slice of lines contain the data rows
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/core.py in get_lines(self, table, newline)
#     304                     or ('\n' not in table + '' and '\r' not in table + '')):
#     305                 with get_readable_fileobj(table,
# --> 306                                           encoding=self.encoding) as fileobj:
#     307                     table = fileobj.read()
#     308             if newline is None:
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers)
#     250                 timeout=remote_timeout, sources=sources,
#     251                 http_headers=http_headers)
# --> 252         fileobj = io.FileIO(name_or_obj, 'r')
#     253         if is_url and not cache:
#     254             delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/lu/data/imaka/onaga/20220123/sta/reduce/Beehive-W/sta008n5wfs_c_scan_clean_stars.txt'

# %%
stars2 = Table.read(root_dir + f'reduce/{fld}/{test_img_base}_clean_stars_stats.fits')
plt.figure()
plt.plot(stars2['mag'], stars2['fwhm_emp'] * scale, 'k.', alpha=0.4)
plt.ylim(0, 1)
plt.xlabel('Mag')
plt.ylabel('Emp. FWHM (")')

plt.figure()
r = np.hypot(stars2['xcentroid'] - (stars2['xcentroid'].max() / 2.0), 
             stars2['ycentroid'] - (stars2['ycentroid'].max() / 2.0)) * scale / 60.0
plt.plot(r, stars2['fwhm_emp'] * scale, 'k.', alpha=0.4)
plt.ylim(0, 1)
plt.xlabel('Radius (amin)')
plt.ylabel('Emp. FWHM (")')
# Out:
# Text(0, 0.5, 'Emp. FWHM (")')

# %% [markdown]
# ## Night-Long Stats

# %%
stats = Table.read(root_dir + 'reduce/stats/stats_LS_5wfs.fits')

# %%
# stats by star 
stats_c = Table.read(root_dir + 'reduce/stats/stats_LS_5wfs.fits')
stats_o = Table.read(root_dir + 'reduce/stats/stats_open.fits')

# stats by stack? => doesn't work
#stats_c = Table.read(root_dir + 'reduce/stacks/fld2_stack_LS_c_stars_stats_mdp.fits')
#stats_o = Table.read(root_dir + 'reduce/stacks/fld2_stack__o_stars_stats.fits')

print(stats.colnames)

plt.figure(figsize=(10,10))
plt.clf()
plt.errorbar(stats_c['Minor Alpha'], stats_c['Beta'], xerr=stats_c['Minor Alpha std'], yerr=stats_c['Beta std'], fmt='r.', label='Closed (LS)')
plt.errorbar(stats_o['Minor Alpha'], stats_o['Beta'], xerr=stats_o['Minor Alpha std'], yerr=stats_o['Beta std'], fmt='k.', label='Open')
plt.xlabel(r'Minor $\alpha$')
plt.ylabel(r'$\beta$')
plt.legend()

plt.figure(figsize=(10,10))
plt.clf()
plt.errorbar(stats_c['Phi'], stats_c['Beta'], xerr=stats_c['Phi std'], yerr=stats_c['Beta std'], fmt='r.', label='Closed (LS)')
plt.errorbar(stats_o['Phi'], stats_o['Beta'], xerr=stats_o['Phi std'], yerr=stats_o['Beta std'], fmt='k.', label='Open')
plt.xlabel(r'$\phi$')
plt.ylabel(r'$\beta$')
plt.legend()
# Out:
# ['Image', 'FILTER', 'BINFAC', 'DATE_UTC', 'TIME_UTC', 'DATE_HST', 'TIME_HST', 'FWHM', 'FWHM_std', 'EE25', 'EE50', 'EE80', 'NEA', 'NEA2', 'xFWHM', 'yFWHM', 'theta', 'emp_fwhm', 'emp_fwhm_std', 'quadrant', 'Index', 'N Stars', 'N Sky', 'N Sky std', 'Amplitude', 'Amplitude std', 'Phi', 'Phi std', 'Beta', 'Beta std', 'Minor Alpha', 'Minor Alpha std', 'Major Alpha', 'Major Alpha std']

# %% [markdown]
# ## Star STATS

# %%
suffixes = list(redu.dict_suffix.keys())
suffixes
# Out:
# ['LS_3wfs_s', 'LS_3wfs_w', 'LS_5wfs', 'open']

# %%
suffixes = ['open', 'LS_3wfs_s', 'LS_3wfs_w', 'LS_5wfs']
plot_stats.plot_stack_stats(night, suffixes=suffixes, root_dir=root_dir + '../../', reduce_dir='sta/reduce/')

# %% [markdown]
# # Time Variation w/MASS-DIMM

# %%
open_file = stats_dir +"stats_open.fits"
closed_file1 = stats_dir+ "stats_LS_3wfs_w.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file1, 'emp_fwhm', "2022-01-21: FWHM and Seeing over time with Closed {3wfs}", plots_dir)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-70d8387551c4> in <module>
#       1 open_file = stats_dir +"stats_open.fits"
#       2 closed_file1 = stats_dir+ "stats_LS_3wfs_w.fits"
# ----> 3 plot_stats.plot_fwhmvt_nomatch(open_file, closed_file1, 'emp_fwhm', "2022-01-21: FWHM and Seeing over time with Closed {3wfs}", plots_dir)
#
# ~/code/imaka/imaka/analysis/plot_stats.py in plot_fwhmvt_nomatch(open_file, closed_file, comp_col, title, plots_dir)
#    1590
#    1591     # Get mass/dimm data
# -> 1592     mass = stats2['MASS']
#    1593     dimm = stats1['DIMM']
#    1594
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1638     def __getitem__(self, item):
#    1639         if isinstance(item, str):
# -> 1640             return self.columns[item]
#    1641         elif isinstance(item, (int, np.integer)):
#    1642             return self.Row(self, item)
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#     237         """
#     238         if isinstance(item, str):
# --> 239             return OrderedDict.__getitem__(self, item)
#     240         elif isinstance(item, (int, np.integer)):
#     241             return list(self.values())[item]
#
# KeyError: 'MASS'

# %%
open_file = stats_dir +"stats_open.fits"
closed_file2 = stats_dir+ "stats_LS_5wfs.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file2, 'emp_fwhm', "2022-01-21: FWHM and Seeing over time with Closed {5wfs}", plots_dir)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-f23270ed71ef> in <module>
#       1 open_file = stats_dir +"stats_open.fits"
#       2 closed_file2 = stats_dir+ "stats_LS_5wfs.fits"
# ----> 3 plot_stats.plot_fwhmvt_nomatch(open_file, closed_file2, 'emp_fwhm', "2022-01-21: FWHM and Seeing over time with Closed {5wfs}", plots_dir)
#
# ~/code/imaka/imaka/analysis/plot_stats.py in plot_fwhmvt_nomatch(open_file, closed_file, comp_col, title, plots_dir)
#    1590
#    1591     # Get mass/dimm data
# -> 1592     mass = stats2['MASS']
#    1593     dimm = stats1['DIMM']
#    1594
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1638     def __getitem__(self, item):
#    1639         if isinstance(item, str):
# -> 1640             return self.columns[item]
#    1641         elif isinstance(item, (int, np.integer)):
#    1642             return self.Row(self, item)
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#     237         """
#     238         if isinstance(item, str):
# --> 239             return OrderedDict.__getitem__(self, item)
#     240         elif isinstance(item, (int, np.integer)):
#     241             return list(self.values())[item]
#
# KeyError: 'MASS'

# %% [markdown]
# # Aggregate Plots

# %%
files = [stats_dir + 'stats_' + suffix + '_mdp.fits' for suffix in suffixes]
print(files)
colors = ['red', 'orange', 'green', 'blue', 'lightgreen', 'cyan']
plot_stats.comp_cdf(files, suffixes, colors)
# Out:
# ['/g/lu/data/imaka/onaga/20220121/sta/reduce/stats/stats_LS_3wfs_s_mdp.fits', '/g/lu/data/imaka/onaga/20220121/sta/reduce/stats/stats_LS_3wfs_w_mdp.fits', '/g/lu/data/imaka/onaga/20220121/sta/reduce/stats/stats_LS_5wfs_mdp.fits', '/g/lu/data/imaka/onaga/20220121/sta/reduce/stats/stats_open_mdp.fits']
# /u/eden/code/imaka/imaka/analysis/plot_stats.py:1869: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(131)
# /u/eden/code/imaka/imaka/analysis/plot_stats.py:1875: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(132)
# /u/eden/code/imaka/imaka/analysis/plot_stats.py:1882: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(133)
# /u/eden/code/imaka/imaka/analysis/plot_stats.py:1869: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(131)
# /u/eden/code/imaka/imaka/analysis/plot_stats.py:1875: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(132)
# /u/eden/code/imaka/imaka/analysis/plot_stats.py:1882: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(133)
# /u/eden/code/imaka/imaka/analysis/plot_stats.py:1869: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(131)
# /u/eden/code/imaka/imaka/analysis/plot_stats.py:1875: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(132)
# /u/eden/code/imaka/imaka/analysis/plot_stats.py:1882: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(133)

# %% [markdown]
# # Field Variability

# %% [markdown]
# ## Closed loop, single exposure

# %%
from importlib import reload
reload(plot_stats)
print(test_img_base)
img_file = root_dir + f'reduce/{fld}/{test_img_base}_clean.fits'
starlist = root_dir +  f'reduce/{fld}/{test_img_base}_clean_stars_stats_mdp.fits'
plot_stats.plot_var(img_file, starlist, "SINGLE: Closed 5wfs(LS)")
# Out:
# sta029n5wfs_c_scan
# Median FWHM           = 0.300"
# Median FWHM (clipped) = 0.300"
# Mean FWHM             = 0.287"
# Mean FWHM (clipped)   = 0.239"
# Stddev FWHM           = 0.445"
# Stddev FWHM (clipped) = 0.114"

# %% [markdown]
# ### Closed loop (3wfs_s)

# %%
img_file = stack_dir + 'beehive_stack_n3wfs_s_c.fits' 
starlist = stack_dir + 'beehive_stack_n3wfs_s_c_stars.txt'
plot_stats.plot_var(img_file, starlist, "STACK: Closed (3wfs_w)")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-f3886f440377> in <module>
#       1 img_file = stack_dir + 'beehive_stack_n3wfs_s_c.fits'
#       2 starlist = stack_dir + 'beehive_stack_n3wfs_s_c_stars.txt'
# ----> 3 plot_stats.plot_var(img_file, starlist, "STACK: Closed (3wfs)")
#
# ~/code/imaka/imaka/analysis/plot_stats.py in plot_var(img_file, starlist, title)
#    1896
#    1897     # Read in stack and starlist
# -> 1898     img, hdr = fits.getdata(img_file, header=True)
#    1899
#    1900     if starlist.endswith('txt'):
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/convenience.py in getdata(filename, header, lower, upper, view, *args, **kwargs)
#     192     mode, closed = _get_file_mode(filename)
#     193
# --> 194     hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     195     try:
#     196         hdu = hdulist[extidx]
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/convenience.py in _getext(filename, mode, ext, extname, extver, *args, **kwargs)
#    1052         raise TypeError('extver alone cannot specify an extension.')
#    1053
# -> 1054     hdulist = fitsopen(filename, mode=mode, **kwargs)
#    1055
#    1056     return hdulist, ext
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     163
#     164     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# --> 165                             lazy_load_hdus, **kwargs)
#     166
#     167
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     401         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     402                              save_backup=save_backup, cache=cache,
# --> 403                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#     404
#     405     @classmethod
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, **kwargs)
#    1050             if not isinstance(fileobj, _File):
#    1051                 # instantiate a FITS file object (ffo)
# -> 1052                 fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1053             # The Astropy mode is determined by the _File initializer if the
#    1054             # supplied mode was None
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     533                     warnings.warn(message, warning_type, stacklevel=2)
#     534
# --> 535             return function(*args, **kwargs)
#     536
#     537         return wrapper
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     173             self._open_fileobj(fileobj, mode, overwrite)
#     174         elif isinstance(fileobj, (str, bytes)):
# --> 175             self._open_filename(fileobj, mode, overwrite)
#     176         else:
#     177             self._open_filelike(fileobj, mode, overwrite)
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, overwrite)
#     562
#     563         if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 564             self._file = fileobj_open(self.name, IO_FITS_MODES[mode])
#     565             self.close_on_error = True
#     566
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/util.py in fileobj_open(filename, mode)
#     390     """
#     391
# --> 392     return open(filename, mode, buffering=0)
#     393
#     394
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/lu/data/imaka/onaga/20220121/sta/reduce/stacks/beehive_stack_n3wfs_s_c.fits'

# %% [markdown]
# ### Closed loop (3wfs_w)

# %%
img_file = stack_dir + 'beehive_stack_n3wfs_w_c.fits' 
starlist = stack_dir + 'beehive_stack_n3wfs_w_c_stars.txt'
plot_stats.plot_var(img_file, starlist, "STACK: Closed (3wfs_s)")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-49d5d3b94e85> in <module>
#       1 img_file = stack_dir + 'beehive_stack_n3wfs_w_c.fits'
#       2 starlist = stack_dir + 'beehive_stack_n3wfs_w_c_stars.txt'
# ----> 3 plot_stats.plot_var(img_file, starlist, "STACK: Closed (3wfs_s)")
#
# ~/code/imaka/imaka/analysis/plot_stats.py in plot_var(img_file, starlist, title)
#    1896
#    1897     # Read in stack and starlist
# -> 1898     img, hdr = fits.getdata(img_file, header=True)
#    1899
#    1900     if starlist.endswith('txt'):
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/convenience.py in getdata(filename, header, lower, upper, view, *args, **kwargs)
#     192     mode, closed = _get_file_mode(filename)
#     193
# --> 194     hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     195     try:
#     196         hdu = hdulist[extidx]
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/convenience.py in _getext(filename, mode, ext, extname, extver, *args, **kwargs)
#    1052         raise TypeError('extver alone cannot specify an extension.')
#    1053
# -> 1054     hdulist = fitsopen(filename, mode=mode, **kwargs)
#    1055
#    1056     return hdulist, ext
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     163
#     164     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# --> 165                             lazy_load_hdus, **kwargs)
#     166
#     167
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     401         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     402                              save_backup=save_backup, cache=cache,
# --> 403                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#     404
#     405     @classmethod
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, **kwargs)
#    1050             if not isinstance(fileobj, _File):
#    1051                 # instantiate a FITS file object (ffo)
# -> 1052                 fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1053             # The Astropy mode is determined by the _File initializer if the
#    1054             # supplied mode was None
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     533                     warnings.warn(message, warning_type, stacklevel=2)
#     534
# --> 535             return function(*args, **kwargs)
#     536
#     537         return wrapper
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     173             self._open_fileobj(fileobj, mode, overwrite)
#     174         elif isinstance(fileobj, (str, bytes)):
# --> 175             self._open_filename(fileobj, mode, overwrite)
#     176         else:
#     177             self._open_filelike(fileobj, mode, overwrite)
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, overwrite)
#     562
#     563         if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 564             self._file = fileobj_open(self.name, IO_FITS_MODES[mode])
#     565             self.close_on_error = True
#     566
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/util.py in fileobj_open(filename, mode)
#     390     """
#     391
# --> 392     return open(filename, mode, buffering=0)
#     393
#     394
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/lu/data/imaka/onaga/20220121/sta/reduce/stacks/beehive_stack_n3wfs_w_c.fits'

# %% [markdown]
# ### Closed loop (5wfs)

# %%
img_file = stack_dir + 'beehive_stack_n5wfs_c.fits'
starlist = stack_dir + 'beehive_stack_n5wfs_c_stars.txt'
plot_stats.plot_var(img_file, starlist, "STACK: Closed (5wfs)")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-3d19550ce625> in <module>
#       1 img_file = stack_dir + 'beehive_stack_n5wfs_c.fits'
#       2 starlist = stack_dir + 'beehive_stack_n5wfs_c_stars.txt'
# ----> 3 plot_stats.plot_var(img_file, starlist, "STACK: Closed (5wfs)")
#
# ~/code/imaka/imaka/analysis/plot_stats.py in plot_var(img_file, starlist, title)
#    1899
#    1900     if starlist.endswith('txt'):
# -> 1901         stars = Table.read(starlist, format='ascii')
#    1902     else:
#    1903         stars = Table.read(starlist)
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/connect.py in __call__(self, *args, **kwargs)
#      59         descriptions = kwargs.pop('descriptions', None)
#      60
# ---> 61         out = registry.read(cls, *args, **kwargs)
#      62
#      63         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/registry.py in read(cls, format, cache, *args, **kwargs)
#     518
#     519         reader = get_reader(format, cls)
# --> 520         data = reader(*args, **kwargs)
#     521
#     522         if not isinstance(data, cls):
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/connect.py in io_read(format, filename, **kwargs)
#      16         format = re.sub(r'^ascii\.', '', format)
#      17         kwargs['format'] = format
# ---> 18     return read(filename, **kwargs)
#      19
#      20
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/ui.py in read(table, guess, **kwargs)
#     338         # through below to the non-guess way so that any problems result in a
#     339         # more useful traceback.
# --> 340         dat = _guess(table, new_kwargs, format, fast_reader)
#     341         if dat is None:
#     342             guess = False
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/ui.py in _guess(table, read_kwargs, format, fast_reader)
#     498
#     499             reader.guessing = True
# --> 500             dat = reader.read(table)
#     501             _read_trace.append({'kwargs': copy.deepcopy(guess_kwargs),
#     502                                 'Reader': reader.__class__,
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/core.py in read(self, table)
#    1263
#    1264         # Get a list of the lines (rows) in the table
# -> 1265         self.lines = self.inputter.get_lines(table, newline=newline)
#    1266
#    1267         # Set self.data.data_lines to a slice of lines contain the data rows
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/ascii/core.py in get_lines(self, table, newline)
#     304                     or ('\n' not in table + '' and '\r' not in table + '')):
#     305                 with get_readable_fileobj(table,
# --> 306                                           encoding=self.encoding) as fileobj:
#     307                     table = fileobj.read()
#     308             if newline is None:
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers)
#     250                 timeout=remote_timeout, sources=sources,
#     251                 http_headers=http_headers)
# --> 252         fileobj = io.FileIO(name_or_obj, 'r')
#     253         if is_url and not cache:
#     254             delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/lu/data/imaka/onaga/20220121/sta/reduce/stacks/beehive_stack_n5wfs_c_stars.txt'
