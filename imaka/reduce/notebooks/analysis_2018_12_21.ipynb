# %% [markdown]
# # 2018-12-21 UT Preliminary Analysis

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import matplotlib.pyplot as plt
from imaka.analysis import plot_stats
from astropy.table import Table
import numpy as np
from importlib import reload
from imaka.reduce.nights import reduce_2018_12_19 as redu

reload(redu)
reload(plot_stats)

root_dir = "/g/lu/data/imaka/onaga/20181219/sta/"
print("Root directory:",root_dir)
stats_dir = root_dir + "reduce/stats/"
plots_dir = root_dir + "reduce/plots/"
stack_dir = root_dir + "reduce/stacks/"
# Out:
# Root directory: /g/lu/data/imaka/onaga/20181219/sta/

# %% [markdown]
# # Time Variation w/MASS-DIMM

# %%
open_file = stats_dir +"stats_open_mdp.fits"
closed_file1 = stats_dir+ "stats_closed_n7_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file1, 'emp_fwhm', "2018-12-21 UT: FWHM and Seeing over time with Closed {bin2}", plots_dir)

# %%
open_file = stats_dir +"stats_open_mdp.fits"
closed_file2 = stats_dir+ "stats_closed_B2_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file2, 'emp_fwhm', "2018-12-21 UT: FWHM and Seeing over time with Closed (LS)", plots_dir)

# %% [markdown]
# # Aggregate Plots

# %%
files = [open_file, closed_file1, closed_file2]
labels = ['Open', 'LS_c', 'LS_Bin2_c']
colors = ['g', 'b', 'purple']
plot_stats.comp_cdf(files, labels, colors)
# Out:
# /u/caylananderson/code/python/imaka/imaka/analysis/plot_stats.py:1859: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(131)
# /u/caylananderson/code/python/imaka/imaka/analysis/plot_stats.py:1866: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(132)
# ...

# %% [markdown]
# # Field Variability

# %% [markdown]
# ### Closed loop (Bin 2)

# %%
img_file = stack_dir + 'orion_stack_closed_B2.fits' 
starlist = stack_dir + 'orion_stack_closed_B2_stars.txt'
plot_stats.plot_var(img_file, starlist, "Closed (B2)")
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# /u/caylananderson/code/python/imaka/imaka/analysis/plot_stats.py:1920: RuntimeWarning: invalid value encountered in sqrt
#   FWHM = 2*abs(m.width_y.value)*np.sqrt((2**(1/m.power.value))-1)*0.08
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]

# %% [markdown]
# ### Closed (LS)

# %%
img_file = stack_dir + "orion_stack_closed_n7.fits"
starlist = stack_dir + "orion_stack_closed_n7_stars.txt"
plot_stats.plot_var(img_file, starlist, "Closed (LS)")
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]

# %% [markdown]
# ### Open

# %%
img_file = stack_dir + "orion_stack_open.fits"
starlist = stack_dir + "orion_stack_open_stars.txt"
plot_stats.plot_var(img_file, starlist, "Open")
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
