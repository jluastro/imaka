# %% [markdown]
# # 2018-12-21 UT Preliminary Analysis

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import matplotlib.pyplot as plt
from imaka.analysis import plot_stats
from astropy.table import Table
import numpy as np
from importlib import reload
from imaka.reduce.nights import reduce_2018_12_21 as redu

reload(redu)
reload(plot_stats)

root_dir = "/g/lu/data/imaka/onaga/20181221/sta/"
print("Root directory:",root_dir)
stats_dir = root_dir + "reduce/stats/"
plots_dir = root_dir + "reduce/plots/"
stack_dir = root_dir + "reduce/stacks/"
# Out:
# Root directory: /g/lu/data/imaka/onaga/20181221/sta/

# %% [markdown]
# # Time Variation w/MASS-DIMM

# %%
open_file = stats_dir +"stats_open_mdp.fits"
closed_file1 = stats_dir+ "stats_closed_n7_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file1, 'emp_fwhm', "2018-12-21 UT: FWHM and Seeing over time with Closed (n7)", plots_dir)

# %%
open_file = stats_dir +"stats_open_mdp.fits"
closed_file2 = stats_dir+ "stats_closed_n1_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file2, 'emp_fwhm', "2018-12-21 UT: FWHM and Seeing over time with Closed (n1)", plots_dir)

# %%
open_file = stats_dir +"stats_open_mdp.fits"
closed_file3 = stats_dir+ "stats_closed_B2_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file3, 'emp_fwhm', "2018-12-21 UT: FWHM and Seeing over time with Closed (B2)", plots_dir)

# %% [markdown]
# # Aggregate Plots

# %%
files = [open_file, closed_file1, closed_file2, closed_file3]
labels = ['Open', 'n7', 'n1', 'B2']
colors = ['g', 'b', 'purple', 'yellow']
plot_stats.comp_cdf(files, labels, colors)
# Out:
# /u/caylananderson/code/python/imaka/imaka/analysis/plot_stats.py:1863: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(131)
# /u/caylananderson/code/python/imaka/imaka/analysis/plot_stats.py:1870: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(132)
# ...

# %% [markdown]
# # Field Variability

# %% [markdown]
# ### Closed loop (Bin 2)

# %%
img_file = stack_dir + 'orion_stack_closed_B2.fits' 
starlist = stack_dir + 'orion_stack_closed_B2_stars.txt'
plot_stats.plot_var(img_file, starlist, "Closed (B2)")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-1de36a554d63> in <module>
#       1 img_file = stack_dir + 'orion_stack_closed_B2.fits'
#       2 starlist = stack_dir + 'orion_stack_closed_B2_stars.txt'
# ----> 3 plot_stats.plot_var(img_file, starlist, "Closed (B2)")
#
# ~/code/python/imaka/imaka/analysis/plot_stats.py in plot_var(img_file, starlist, title)
#    1892
#    1893     # Read in stack and starlist
# -> 1894     img, hdr = fits.getdata(img_file, header=True)
#    1895     stars = Table.read(starlist, format='ascii')
#    1896     N_stars = len(stars)
#
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/io/fits/convenience.py in getdata(filename, header, lower, upper, view, *args, **kwargs)
#     187     mode, closed = _get_file_mode(filename)
#     188
# --> 189     hdulist, extidx = _getext(filename, mode, *args, **kwargs)
# ...

# %% [markdown]
# ### Closed (LS)

# %%
img_file = stack_dir + "orion_stack_closed_n7.fits"
starlist = stack_dir + "orion_stack_closed_n7_stars.txt"
plot_stats.plot_var(img_file, starlist, "Closed (LS)")

# %% [markdown]
# ### Open

# %%
img_file = stack_dir + "orion_stack_open.fits"
starlist = stack_dir + "orion_stack_open_stars.txt"
plot_stats.plot_var(img_file, starlist, "Open")
