# %% [markdown]
# # 20181219 Initial Analysis

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import matplotlib.pyplot as plt
from astropy.table import Table
import numpy as np
from importlib import reload
from imaka.analysis import plot_stats

root_dir = "/Volumes/DATA5/imaka/20181221/sta/"
root_dir = "/Users/fatimaabdurrahman/Desktop/Research/RUN9/20181221/sta/"
stats_dir = root_dir + "reduce/stats/"
plots_dir = root_dir + "reduce/plots/"
stack_dir = root_dir + "reduce/stacks/"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Time Variation w/MASS-DIMM

# %%
open_file = stats_dir +"stats_open_mdp.fits"
closed_file1 = stats_dir+ "stats_closed_B2_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file1, 'emp_fwhm', "2018-12-21: FWHM and Seeing over time with Closed {bin2}", plots_dir)

# %%
open_file = stats_dir +"stats_open_mdp.fits"
closed_file2 = stats_dir+ "stats_closed_n7_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file2, 'emp_fwhm', "2018-12-21: FWHM and Seeing over time with Closed (nrej7)", plots_dir)

# %%
open_file = stats_dir +"stats_open_mdp.fits"
closed_file3 = stats_dir+ "stats_closed_n1_mdp.fits"
plot_stats.plot_fwhmvt_nomatch(open_file, closed_file3, 'emp_fwhm', "2018-12-21: FWHM and Seeing over time with Closed (nrej1)", plots_dir)

# %% [markdown]
# # Aggregate Plots

# %%
files = [open_file, closed_file1, closed_file2, closed_file3]
labels = ['Open', 'bin2', 'nrej7', 'nrej1']
colors = ['k', 'g', 'b', 'purple']
plot_stats.comp_cdf(files, labels, colors)
# Out:
# /Users/fatimaabdurrahman/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6201: RuntimeWarning: invalid value encountered in true_divide
#   m = (m.astype(float) / db) / m.sum()

# %% [markdown]
# # Field Variability

# %% [markdown]
# ### Closed loop (Bin 2)

# %%
img_file = stack_dir + 'orion_stack_closed_B2.fits' 
starlist = stack_dir + 'orion_stack_closed_B2_stars.txt'
plot_stats.plot_var_minmax(img_file, starlist, "Closed (B2)", xmin=0.5, xmax=0.7)
# Out:
# N Stars:  132
# Mean:  0.6128635289164648
# Median:  0.6154555418519818
# Std Dev:  0.027327017527834778

# %% [markdown]
# ### Closed (LS)

# %%
img_file = stack_dir + "orion_stack_closed_n7.fits"
starlist = stack_dir + "orion_stack_closed_n7_stars.txt"
plot_stats.plot_var_minmax(img_file, starlist, "Closed (LS)", xmin=0.72, xmax=0.88)
# Out:
# N Stars:  109
# Mean:  0.8047026680855239
# Median:  0.8036159865727135
# Std Dev:  0.02934189078656861

# %% [markdown]
# ### Open

# %%
img_file = stack_dir + "orion_stack_open.fits"
starlist = stack_dir + "orion_stack_open_stars.txt"
plot_stats.plot_var_minmax(img_file, starlist, "Open", xmin=0.85, xmax=1)
# Out:
# N Stars:  62
# Mean:  0.954517357724346
# Median:  0.9541086871813891
# Std Dev:  0.029157603009969127
